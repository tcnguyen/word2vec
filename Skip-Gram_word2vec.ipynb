# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:47, 654kB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
import re
from collections import Counter

def preprocess(text):

    # Replace punctuation with tokens so we can use them in our model
    text = text.lower()
    text = text.replace('.', ' <PERIOD> ')
    text = text.replace(',', ' <COMMA> ')
    text = text.replace('"', ' <QUOTATION_MARK> ')
    text = text.replace(';', ' <SEMICOLON> ')
    text = text.replace('!', ' <EXCLAMATION_MARK> ')
    text = text.replace('?', ' <QUESTION_MARK> ')
    text = text.replace('(', ' <LEFT_PAREN> ')
    text = text.replace(')', ' <RIGHT_PAREN> ')
    text = text.replace('--', ' <HYPHENS> ')
    text = text.replace('?', ' <QUESTION_MARK> ')
    # text = text.replace('\n', ' <NEW_LINE> ')
    text = text.replace(':', ' <COLON> ')
    words = text.split()
    
    # Remove all words with  5 or fewer occurences
    word_counts = Counter(words)
    trimmed_words = [word for word in words if word_counts[word] > 5]

    return trimmed_words

# %%
words = preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
def create_lookup_tables(words):
    """
    Create lookup tables for vocabulary
    :param words: Input list of words
    :return: A tuple of dicts.  The first dict....
    """
    word_counts = Counter(words)
    sorted_vocab = sorted(word_counts, key=word_counts.get, reverse=True)
    int_to_vocab = {ii: word for ii, word in enumerate(sorted_vocab)}
    vocab_to_int = {word: ii for ii, word in int_to_vocab.items()}

    return vocab_to_int, int_to_vocab

# %%
vocab_to_int, int_to_vocab = create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
print("original text length:", len(text))
print("length of text after removing words with frequency less than 5:", len(int_words))
print("vocabulary size", len(vocab_to_int))
# Out:
# original text length: 100000000
# length of text after removing words with frequency less than 5: 16680599
# vocabulary size 63641

# %%
word_counts = Counter(int_words)
total_words =len(int_words)
word_freqs = {word: count/total_count for word, count in word_counts.items()}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-96fdd04e2fd8> in <module>()
#       1 word_counts = Counter(int_words)
#       2 total_words =len(int_words)
# ----> 3 word_freqs = {word: count/total_count for word, count in word_counts.items()}
#
# <ipython-input-66-96fdd04e2fd8> in <dictcomp>(.0)
#       1 word_counts = Counter(int_words)
#       2 total_words =len(int_words)
# ----> 3 word_freqs = {word: count/total_count for word, count in word_counts.items()}
#
# NameError: name 'total_count' is not defined

# %%
[(int_to_vocab[x[0]],x[1], x[1]/total_words) for x in word_counts.most_common(10)]
# Out:
# [('the', 1061396, 0.06363056866243233),
#  ('of', 593677, 0.035590868169662254),
#  ('and', 416629, 0.02497686084294695),
#  ('one', 411764, 0.02468520465002486),
#  ('in', 372201, 0.022313407330276328),
#  ('a', 325873, 0.01953604903516954),
#  ('to', 316376, 0.018966704972645167),
#  ('zero', 264975, 0.015885220908433802),
#  ('nine', 250430, 0.015013249823942174),
#  ('two', 192644, 0.011548985740859786)]

# %% [markdown]
# The frequency of top 10 most frequent words goes from 1% to 6% (the)

# %% [markdown]
# ### word frequency distribution

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
word_frequencies = [x/total_words for x in word_counts.values()]
word_frequencies.sort(reverse = True)
log_word_prequencies = np.log10(word_frequencies)

# %%
plt.boxplot(log_word_prequencies)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fbee37b3be0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fbee372f0f0>,
#   <matplotlib.lines.Line2D at 0x7fbee36cc7b8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fbee35f5898>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fbee36732b0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fbee377e6d8>,
#   <matplotlib.lines.Line2D at 0x7fbee36e9358>]}

# %%
sns.distplot(log_word_prequencies)

# %%
np.random.seed(100)
## Your code here
thresold = 1e-5
train_words = [w for w in int_words if np.random.random() < 1 - np.sqrt(thresold/word_freqs[w])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    return words[max(idx-R,0):idx] + words[idx+1: idx+R+1]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
import gc
gc.collect()
# Out:
# 0

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None,1], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  100 # Number of embedding features 
with train_graph.as_default():
    # create embedding weight matrix here
    embedding =   tf.Variable(tf.random_uniform(shape=[n_vocab, n_embedding], maxval=1, minval=-1))
                              # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal(shape=[n_vocab, n_embedding], mean=0, stddev= 1./np.sqrt(n_embedding)))
    # create softmax biases here
    softmax_b = tf.Variable(tf.zeros(shape=[n_vocab]))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss ( weights = softmax_w,
        biases = softmax_b,
        labels = labels,
        inputs = embed,
        num_sampled = n_sampled,
        num_classes = n_vocab,
        num_true=1
    )
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-89-6cd0def8ff91>:14: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 9.0047 0.1365 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 8.0812 0.1282 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 6.6634 0.1275 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.7156 0.1280 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.3180 0.1277 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 4.9375 0.1274 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 4.6773 0.1275 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 4.4571 0.1275 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 4.5712 0.1273 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 4.4918 0.1275 sec/batch
# Nearest to six: joseph, neglected, frameworks, remains, life, bra, part, started,
# Nearest to b: games, founded, needed, late, put, victory, little, advocate,
# Nearest to have: help, mediterranean, governments, longest, e, me, run, local,
# Nearest to system: continental, former, sought, characteristic, release, different, less, asian,
# Nearest to with: french, army, television, show, argued, called, onto, few,
# Nearest to or: out, mount, received, hot, very, whilst, discovered, quite,
# Nearest to he: fire, name, e, due, went, often, believed, many,
# Nearest to eight: development, return, paul, theory, rooms, american, international, dedicated,
# Nearest to police: was, samuel, prevent, distinction, jamahiriya, pinker, grimoires, cem,
# Nearest to recorded: resources, seems, lorne, sinaltrainal, battalion, peter, business, seuss,
# Nearest to quite: distance, or, use, must, relationship, roused, very, successfully,
# Nearest to pre: casein, trick, ayeyarwady, dual, self, intention, syrup, aeolian,
# Nearest to creation: confidences, salvia, lieutenant, michael, aquarii, ferenc, li, chloride,
# Nearest to dr: sealing, wiring, wiltshire, items, traditionally, peter, deutsch, galli,
# Nearest to engineering: against, becomes, interested, ionosphere, nervosa, applied, baywatch, rudiments,
# Nearest to cost: semitic, european, copper, increasing, john, surrounding, richard, quebec,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 4.4162 0.1293 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 4.3359 0.1280 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.2922 0.1278 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.2785 0.1279 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.2890 0.1277 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.2721 0.1275 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.2737 0.1274 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.1687 0.1273 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.2059 0.1299 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.2059 0.1311 sec/batch
# Nearest to six: joseph, portion, started, october, neglected, frameworks, views, canon,
# Nearest to b: games, founded, late, advocate, victory, put, possession, feet,
# Nearest to have: help, mediterranean, governments, longest, shall, me, capacity, which,
# Nearest to system: continental, sought, release, characteristic, completely, former, asian, monroe,
# Nearest to with: argued, influences, onto, called, formally, television, army, situation,
# Nearest to or: out, mount, operate, quite, shall, identify, received, keep,
# Nearest to he: fire, name, district, believed, supports, e, went, isn,
# Nearest to eight: rooms, approximately, return, development, paul, international, american, dedicated,
# Nearest to police: prevent, distinction, samuel, was, met, iso, trademark, price,
# Nearest to recorded: resources, seems, presented, peter, entitled, battalion, business, words,
# Nearest to quite: successfully, or, distance, physical, likely, relationship, use, very,
# Nearest to pre: dual, trick, self, intention, brand, disorders, well, derives,
# Nearest to creation: confidences, michael, lieutenant, oxford, opponent, corporate, li, selling,
# Nearest to dr: items, un, neutral, sealing, wiring, destroyed, peter, traditionally,
# Nearest to engineering: interested, against, becomes, past, applied, destroyed, historian, baywatch,
# Nearest to cost: european, semitic, surrounding, copper, increasing, things, richard, john,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.1865 0.1326 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.1470 0.1297 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.0792 0.1286 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.0933 0.1311 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.1362 0.1269 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.1195 0.1276 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.0949 0.1274 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.1597 0.1275 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.1336 0.1270 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 3.9784 0.1277 sec/batch
# Nearest to six: joseph, october, portion, na, parameters, started, neglected, series,
# Nearest to b: founded, games, advocate, late, feet, possession, residents, put,
# Nearest to have: help, mediterranean, governments, longest, campaigns, which, linked, capacity,
# Nearest to system: continental, sought, less, release, characteristic, monroe, completely, asian,
# Nearest to with: argued, influences, called, onto, formally, interior, television, french,
# Nearest to or: out, operate, mount, quite, identify, shall, entertainment, received,
# Nearest to he: fire, name, went, district, believed, supports, isn, died,
# Nearest to eight: rooms, approximately, experts, international, paul, return, american, five,
# Nearest to police: prevent, samuel, distinction, trademark, was, iso, met, price,
# Nearest to recorded: resources, seems, portrayed, battalion, presented, entitled, peter, depends,
# Nearest to quite: successfully, or, very, physical, use, distance, jurisdiction, conference,
# Nearest to pre: trick, dual, disorders, self, brand, intention, derives, known,
# Nearest to creation: confidences, opponent, lieutenant, regularly, michael, corporate, oxford, li,
# Nearest to dr: items, neutral, coastline, un, involving, sealing, wiring, destroyed,
# Nearest to engineering: interested, against, becomes, past, youth, historian, applied, destroyed,
# Nearest to cost: semitic, european, copper, surrounding, increasing, sections, sign, quebec,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.1678 0.1300 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.0680 0.1275 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.1020 0.1273 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.1039 0.1270 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.0934 0.1273 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.0684 0.1273 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.0848 0.1279 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.0769 0.1273 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.0860 0.1275 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.0767 0.1273 sec/batch
# Nearest to six: joseph, october, na, started, parameters, sudden, series, portion,
# Nearest to b: founded, games, advocate, residents, feet, victory, possession, late,
# Nearest to have: help, mediterranean, governments, linked, longest, campaigns, which, they,
# Nearest to system: continental, sought, less, consist, monroe, household, defeat, release,
# Nearest to with: argued, influences, called, onto, formally, sometimes, an, interior,
# Nearest to or: out, quite, operate, identify, mount, keep, entertainment, nothing,
# Nearest to he: fire, went, believed, name, died, district, supports, belong,
# Nearest to eight: rooms, approximately, paul, international, experts, five, return, september,
# Nearest to police: prevent, trademark, samuel, distinction, iso, was, met, price,
# Nearest to recorded: seems, resources, portrayed, presented, battalion, entitled, could, depends,
# Nearest to quite: or, very, successfully, physical, use, likely, jurisdiction, distance,
# Nearest to pre: trick, dual, disorders, self, derives, intention, brand, participate,
# Nearest to creation: confidences, li, opponent, lieutenant, regularly, corporate, oxford, michael,
# Nearest to dr: neutral, coastline, un, items, involving, wiring, peter, sealing,
# Nearest to engineering: interested, past, becomes, against, platforms, historian, gold, complete,
# Nearest to cost: european, semitic, copper, surrounding, sign, sections, increasing, things,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.0537 0.1296 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.0509 0.1280 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.0745 0.1273 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.0596 0.1274 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.0107 0.1270 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.0132 0.1272 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 3.9871 0.1274 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 4.0328 0.1282 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 4.0212 0.1286 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 4.0037 0.1285 sec/batch
# Nearest to six: joseph, october, na, started, parameters, sudden, series, neglected,
# Nearest to b: founded, games, residents, feet, advocate, carriers, american, late,
# Nearest to have: help, mediterranean, governments, linked, wake, they, longest, which,
# Nearest to system: sought, continental, less, characteristic, household, consist, monroe, required,
# Nearest to with: called, influences, argued, onto, communion, formally, sometimes, reviews,
# Nearest to or: out, quite, operate, identify, mount, nothing, keep, very,
# Nearest to he: fire, died, went, believed, isn, name, belong, close,
# Nearest to eight: rooms, american, approximately, british, paul, international, experts, william,
# Nearest to police: trademark, prevent, samuel, was, met, distinction, iso, price,
# Nearest to recorded: seems, resources, battalion, portrayed, could, gif, presented, explosion,
# Nearest to quite: or, very, successfully, use, physical, likely, distance, jurisdiction,
# Nearest to pre: trick, disorders, dual, self, intention, brand, derives, known,
# Nearest to creation: confidences, opponent, li, regularly, corporate, lieutenant, trademark, oxford,
# Nearest to dr: coastline, neutral, un, peter, sealing, nine, wiring, destroyed,
# Nearest to engineering: interested, platforms, past, becomes, against, capitalist, complete, gordon,
# Nearest to cost: copper, semitic, european, enlightenment, sign, sections, surrounding, things,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 4.0596 0.1308 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 4.0614 0.1282 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 4.0317 0.1288 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 4.0474 0.1280 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 4.0052 0.1283 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 4.0280 0.1279 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 4.0189 0.1279 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 4.0244 0.1282 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 4.0368 0.1282 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 4.0149 0.1287 sec/batch
# Nearest to six: joseph, october, na, started, sudden, accomplished, january, parameters,
# Nearest to b: founded, carriers, games, feet, residents, entropy, corps, usa,
# Nearest to have: help, mediterranean, linked, wake, governments, had, they, campaigns,
# Nearest to system: sought, continental, less, progress, characteristic, household, monroe, required,
# Nearest to with: called, communion, influences, onto, argued, formally, gaining, off,
# Nearest to or: out, quite, operate, identify, mount, keep, nothing, animals,
# Nearest to he: fire, died, went, believed, asked, close, isn, nobility,
# Nearest to eight: rooms, approximately, william, richard, andrew, merchant, paul, five,
# Nearest to police: trademark, prevent, samuel, was, met, price, iso, distinction,
# Nearest to recorded: seems, resources, battalion, portrayed, could, gif, presented, explosion,
# Nearest to quite: or, very, successfully, use, physical, likely, relationship, jurisdiction,
# Nearest to pre: trick, disorders, dual, brand, self, known, derives, intention,
# Nearest to creation: confidences, opponent, li, regularly, trademark, lieutenant, corporate, signal,
# Nearest to dr: coastline, neutral, un, peter, destroyed, sealing, nine, wiring,
# Nearest to engineering: platforms, interested, past, complete, capitalist, becomes, gordon, imprisoned,
# Nearest to cost: enlightenment, copper, semitic, sections, increasing, surrounding, sign, meets,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 4.0331 0.1297 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 3.9547 0.1274 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 3.9615 0.1276 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 3.9940 0.1281 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 4.0505 0.1285 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 4.0119 0.1283 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 4.0482 0.1283 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 4.0183 0.1284 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 3.9876 0.1281 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 3.9971 0.1280 sec/batch
# Nearest to six: joseph, na, october, started, sudden, series, january, accomplished,
# Nearest to b: founded, feet, carriers, usa, musician, residents, jacques, games,
# Nearest to have: help, mediterranean, linked, had, wake, they, governments, likely,
# Nearest to system: continental, sought, less, characteristic, household, required, copy, release,
# Nearest to with: called, influences, communion, argued, onto, off, gaining, cool,
# Nearest to or: quite, out, identify, operate, keep, nothing, animals, mount,
# Nearest to he: fire, died, asked, went, believed, isn, close, him,
# Nearest to eight: rooms, approximately, andrew, paul, william, merchant, american, british,
# Nearest to police: trademark, prevent, samuel, roberts, met, was, price, iso,
# Nearest to recorded: seems, battalion, resources, portrayed, gif, calcium, could, entitled,
# Nearest to quite: very, or, use, likely, successfully, physical, properly, jurisdiction,
# Nearest to pre: trick, disorders, dual, brand, self, known, derives, participate,
# Nearest to creation: confidences, opponent, li, corporate, trademark, regularly, lieutenant, assistance,
# Nearest to dr: coastline, peter, neutral, un, sealing, destroyed, wiring, nine,
# Nearest to engineering: platforms, interested, past, complete, capitalist, dish, imprisoned, gordon,
# Nearest to cost: enlightenment, copper, sign, meets, sections, changed, semitic, lawyer,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 4.0099 0.1292 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 4.0128 0.1276 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 4.0066 0.1278 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 3.9963 0.1273 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 3.9831 0.1278 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 4.0066 0.1275 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 4.0368 0.1282 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 4.0108 0.1285 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 3.9792 0.1283 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 4.0000 0.1280 sec/batch
# Nearest to six: joseph, na, started, october, xiv, live, diary, roy,
# Nearest to b: founded, carriers, feet, usa, musician, entropy, residents, friedrich,
# Nearest to have: help, had, linked, mediterranean, wake, likely, they, governments,
# Nearest to system: continental, household, characteristic, copy, sought, less, progress, required,
# Nearest to with: called, communion, influences, argued, off, onto, gaining, cool,
# Nearest to or: quite, identify, out, keep, mount, operate, hot, animals,
# Nearest to he: died, fire, asked, went, father, isn, close, believed,
# Nearest to eight: rooms, andrew, paul, architectural, merchant, approximately, william, five,
# Nearest to police: trademark, roberts, samuel, prevent, met, was, iso, trade,
# Nearest to recorded: seems, battalion, resources, gif, portrayed, calcium, could, entitled,
# Nearest to quite: very, or, likely, use, successfully, properly, physical, relationship,
# Nearest to pre: trick, disorders, dual, known, self, brand, intention, derives,
# Nearest to creation: confidences, li, trademark, opponent, regularly, corporate, lieutenant, assistance,
# Nearest to dr: coastline, atlas, peter, nine, un, destroyed, neutral, angeles,
# Nearest to engineering: platforms, interested, past, complete, capitalist, gold, dish, imprisoned,
# Nearest to cost: enlightenment, copper, sections, changed, sign, finger, meets, button,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 3.9847 0.1295 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 4.0289 0.1277 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 3.9965 0.1278 sec/batch
# Epoch 1/10 Iteration: 8400 Avg. Training loss: 3.9658 0.1280 sec/batch
# Epoch 1/10 Iteration: 8500 Avg. Training loss: 4.0249 0.1276 sec/batch
# Epoch 1/10 Iteration: 8600 Avg. Training loss: 4.0298 0.1278 sec/batch
# Epoch 1/10 Iteration: 8700 Avg. Training loss: 3.9482 0.1281 sec/batch
# Epoch 1/10 Iteration: 8800 Avg. Training loss: 3.9857 0.1282 sec/batch
# Epoch 1/10 Iteration: 8900 Avg. Training loss: 4.0113 0.1284 sec/batch
# Epoch 1/10 Iteration: 9000 Avg. Training loss: 3.9947 0.1275 sec/batch
# Nearest to six: na, started, joseph, october, diary, xiv, live, roy,
# Nearest to b: feet, carriers, f, entropy, founded, des, residents, usa,
# Nearest to have: had, help, linked, mediterranean, wake, supernatural, likely, governments,
# Nearest to system: continental, copy, characteristic, progress, shi, household, release, required,
# Nearest to with: called, communion, influences, off, onto, greatly, while, gaining,
# Nearest to or: identify, keep, quite, out, mount, operate, animals, hot,
# Nearest to he: died, asked, fire, went, isn, father, she, him,
# Nearest to eight: rooms, andrew, architectural, approximately, backing, five, paul, moscow,
# Nearest to police: roberts, trademark, prevent, samuel, trade, matthew, met, comics,
# Nearest to recorded: seems, portrayed, battalion, resources, gif, calcium, could, entitled,
# Nearest to quite: very, or, likely, properly, use, successfully, phrases, physical,
# Nearest to pre: trick, disorders, dual, self, brand, known, intention, derives,
# Nearest to creation: confidences, li, opponent, trademark, regularly, corporate, lieutenant, oxford,
# Nearest to dr: coastline, atlas, peter, sect, destroyed, nine, pa, brigade,
# Nearest to engineering: platforms, interested, past, capitalist, complete, alike, dish, gold,
# Nearest to cost: enlightenment, copper, meets, finger, changed, sign, sections, button,
# Epoch 1/10 Iteration: 9100 Avg. Training loss: 3.5567 0.1296 sec/batch
# Epoch 1/10 Iteration: 9200 Avg. Training loss: 3.8359 0.1277 sec/batch
# Epoch 1/10 Iteration: 9300 Avg. Training loss: 3.7737 0.1303 sec/batch
# Epoch 1/10 Iteration: 9400 Avg. Training loss: 3.8514 0.1279 sec/batch
# Epoch 1/10 Iteration: 9500 Avg. Training loss: 3.9909 0.1284 sec/batch
# Epoch 1/10 Iteration: 9600 Avg. Training loss: 3.9394 0.1283 sec/batch
# Epoch 1/10 Iteration: 9700 Avg. Training loss: 3.9962 0.1282 sec/batch
# Epoch 1/10 Iteration: 9800 Avg. Training loss: 3.9757 0.1287 sec/batch
# Epoch 1/10 Iteration: 9900 Avg. Training loss: 3.9815 0.1282 sec/batch
# Epoch 1/10 Iteration: 10000 Avg. Training loss: 3.9724 0.1283 sec/batch
# Nearest to six: started, xiv, na, diary, joseph, october, sponsored, detroit,
# Nearest to b: musician, player, carriers, jacques, d, footballer, feet, games,
# Nearest to have: had, linked, help, supernatural, mediterranean, likely, has, many,
# Nearest to system: continental, characteristic, shi, copy, progress, household, required, less,
# Nearest to with: called, communion, off, onto, influences, greatly, cool, electromagnetic,
# Nearest to or: identify, quite, keep, out, just, mount, animals, hot,
# Nearest to he: died, asked, fire, isn, went, close, she, father,
# Nearest to eight: rooms, andrew, backing, architectural, paul, winners, approximately, moscow,
# Nearest to police: roberts, prevent, samuel, trademark, trade, met, matthew, comics,
# Nearest to recorded: seems, portrayed, battalion, entitled, diplomat, resources, gif, calcium,
# Nearest to quite: very, or, likely, properly, phrases, use, successfully, physical,
# Nearest to pre: trick, disorders, self, brand, dual, known, cardinals, intention,
# Nearest to creation: confidences, opponent, li, oxford, lieutenant, trademark, corporate, updated,
# Nearest to dr: peter, coastline, atlas, sect, nine, pa, brigade, angeles,
# Nearest to engineering: platforms, interested, capitalist, alike, complete, past, gordon, gold,
# Nearest to cost: enlightenment, copper, finger, meets, sign, deck, versions, omega,
# Epoch 1/10 Iteration: 10100 Avg. Training loss: 4.0238 0.1301 sec/batch
# Epoch 1/10 Iteration: 10200 Avg. Training loss: 3.9349 0.1285 sec/batch
# Epoch 1/10 Iteration: 10300 Avg. Training loss: 3.9972 0.1282 sec/batch
# Epoch 1/10 Iteration: 10400 Avg. Training loss: 3.9919 0.1286 sec/batch
# Epoch 1/10 Iteration: 10500 Avg. Training loss: 3.9521 0.1279 sec/batch
# Epoch 1/10 Iteration: 10600 Avg. Training loss: 3.9688 0.1281 sec/batch
# Epoch 1/10 Iteration: 10700 Avg. Training loss: 4.0130 0.1286 sec/batch
# Epoch 1/10 Iteration: 10800 Avg. Training loss: 3.9930 0.1283 sec/batch
# Epoch 1/10 Iteration: 10900 Avg. Training loss: 4.0151 0.1284 sec/batch
# Epoch 1/10 Iteration: 11000 Avg. Training loss: 3.8761 0.1281 sec/batch
# Nearest to six: xiv, started, na, live, diary, sponsored, october, aimed,
# Nearest to b: carriers, f, feet, entropy, des, phrenology, player, founded,
# Nearest to have: had, linked, help, supernatural, has, wake, many, individuals,
# Nearest to system: continental, copy, shi, progress, characteristic, household, code, required,
# Nearest to with: called, communion, off, influences, greatly, afc, electromagnetic, cool,
# Nearest to or: identify, keep, quite, mount, just, expression, hot, animals,
# Nearest to he: died, asked, fire, went, father, she, isn, close,
# Nearest to eight: rooms, andrew, backing, merchant, architectural, fm, semi, winners,
# Nearest to police: roberts, prevent, trademark, samuel, trade, demonstrations, iranian, pinker,
# Nearest to recorded: seems, battalion, portrayed, diplomat, entitled, company, next, gif,
# Nearest to quite: very, likely, or, properly, phrases, use, more, successfully,
# Nearest to pre: trick, disorders, brand, known, self, dual, cardinals, important,
# Nearest to creation: confidences, trademark, li, assistance, corporate, opponent, lieutenant, oxford,
# Nearest to dr: peter, sect, atlas, coastline, nine, brigade, pa, swimming,
# Nearest to engineering: platforms, complete, interested, capitalist, alike, gordon, gold, madagascar,
# Nearest to cost: enlightenment, copper, finger, meets, because, amber, excessive, sections,
# Epoch 1/10 Iteration: 11100 Avg. Training loss: 3.8976 0.1296 sec/batch
# Epoch 1/10 Iteration: 11200 Avg. Training loss: 3.9524 0.1325 sec/batch
# Epoch 1/10 Iteration: 11300 Avg. Training loss: 3.8434 0.1295 sec/batch
# Epoch 1/10 Iteration: 11400 Avg. Training loss: 3.9566 0.1280 sec/batch
# Epoch 1/10 Iteration: 11500 Avg. Training loss: 3.9963 0.1278 sec/batch
# Epoch 1/10 Iteration: 11600 Avg. Training loss: 3.9834 0.1278 sec/batch
# Epoch 1/10 Iteration: 11700 Avg. Training loss: 3.8605 0.1274 sec/batch
# Epoch 1/10 Iteration: 11800 Avg. Training loss: 3.9462 0.1276 sec/batch
# Epoch 1/10 Iteration: 11900 Avg. Training loss: 3.9354 0.1275 sec/batch
# Epoch 1/10 Iteration: 12000 Avg. Training loss: 4.0012 0.1271 sec/batch
# Nearest to six: xiv, diary, started, joseph, na, roy, lex, live,
# Nearest to b: d, musician, scottish, footballer, player, friedrich, jacques, american,
# Nearest to have: had, linked, help, has, many, individuals, supernatural, interest,
# Nearest to system: continental, shi, progress, operating, household, characteristic, servers, copy,
# Nearest to with: called, off, communion, while, gaining, onto, cool, influences,
# Nearest to or: identify, keep, quite, just, chains, mount, animals, expression,
# Nearest to he: asked, died, fire, went, she, met, father, him,
# Nearest to eight: andrew, rooms, backing, architectural, paul, five, british, ambiguous,
# Nearest to police: roberts, prevent, trademark, demonstrations, samuel, trade, iranian, met,
# Nearest to recorded: seems, portrayed, battalion, entitled, gif, tour, diplomat, next,
# Nearest to quite: very, likely, properly, or, phrases, use, paying, more,
# Nearest to pre: trick, disorders, self, brand, known, important, intention, dual,
# Nearest to creation: confidences, trademark, oxford, opponent, updated, assistance, li, corporate,
# Nearest to dr: peter, sect, nine, pa, swimming, atlas, coastline, mother,
# Nearest to engineering: platforms, complete, capitalist, alike, gold, madagascar, interested, ionosphere,
# Nearest to cost: copper, enlightenment, finger, meets, because, sections, amber, increasing,
# Epoch 2/10 Iteration: 12100 Avg. Training loss: 4.0123 0.0602 sec/batch
# Epoch 2/10 Iteration: 12200 Avg. Training loss: 3.9986 0.1269 sec/batch
# Epoch 2/10 Iteration: 12300 Avg. Training loss: 3.9858 0.1271 sec/batch
# Epoch 2/10 Iteration: 12400 Avg. Training loss: 3.9990 0.1271 sec/batch
# Epoch 2/10 Iteration: 12500 Avg. Training loss: 3.8979 0.1271 sec/batch
# Epoch 2/10 Iteration: 12600 Avg. Training loss: 3.9390 0.1276 sec/batch
# Epoch 2/10 Iteration: 12700 Avg. Training loss: 3.9148 0.1272 sec/batch
# Epoch 2/10 Iteration: 12800 Avg. Training loss: 3.7854 0.1269 sec/batch
# Epoch 2/10 Iteration: 12900 Avg. Training loss: 3.8496 0.1272 sec/batch
# Epoch 2/10 Iteration: 13000 Avg. Training loss: 3.9707 0.1272 sec/batch
# Nearest to six: diary, xiv, started, joseph, na, neglected, julia, lex,
# Nearest to b: musician, d, player, footballer, scottish, jacques, friedrich, painter,
# Nearest to have: had, linked, has, help, many, individuals, supernatural, interest,
# Nearest to system: continental, operating, progress, shi, copy, characteristic, servers, household,
# Nearest to with: called, while, off, communion, onto, gaining, greatly, sister,
# Nearest to or: identify, just, keep, mount, quite, animals, whilst, hot,
# Nearest to he: asked, died, met, fire, went, she, himself, father,
# Nearest to eight: andrew, backing, rooms, five, merchant, paul, british, activist,
# Nearest to police: roberts, prevent, demonstrations, trademark, trade, samuel, pinker, grimoires,
# Nearest to recorded: seems, battalion, portrayed, gif, entitled, company, next, tour,
# Nearest to quite: very, likely, properly, phrases, or, paying, use, more,
# Nearest to pre: trick, disorders, self, known, brand, important, dual, intention,
# Nearest to creation: confidences, opponent, trademark, li, oxford, assistance, corporate, updated,
# Nearest to dr: peter, coastline, sect, swimming, sealing, pa, nine, father,
# Nearest to engineering: platforms, complete, gold, ionosphere, alike, madagascar, capitalist, gordon,
# Nearest to cost: enlightenment, copper, meets, amber, finger, deck, button, excessive,
# Epoch 2/10 Iteration: 13100 Avg. Training loss: 3.9338 0.1290 sec/batch
# Epoch 2/10 Iteration: 13200 Avg. Training loss: 3.9377 0.1275 sec/batch
# Epoch 2/10 Iteration: 13300 Avg. Training loss: 3.9190 0.1277 sec/batch
# Epoch 2/10 Iteration: 13400 Avg. Training loss: 3.9041 0.1276 sec/batch
# Epoch 2/10 Iteration: 13500 Avg. Training loss: 3.9842 0.1277 sec/batch
# Epoch 2/10 Iteration: 13600 Avg. Training loss: 3.9622 0.1271 sec/batch
# Epoch 2/10 Iteration: 13700 Avg. Training loss: 4.0050 0.1271 sec/batch
# Epoch 2/10 Iteration: 13800 Avg. Training loss: 3.9412 0.1281 sec/batch
# Epoch 2/10 Iteration: 13900 Avg. Training loss: 3.9797 0.1279 sec/batch
# Epoch 2/10 Iteration: 14000 Avg. Training loss: 3.9718 0.1278 sec/batch
# Nearest to six: xiv, started, diary, na, neglected, live, lex, julia,
# Nearest to b: musician, footballer, player, scottish, d, f, jacques, carriers,
# Nearest to have: had, has, linked, many, help, individuals, interest, supernatural,
# Nearest to system: continental, operating, shi, progress, copy, required, servers, household,
# Nearest to with: called, off, while, communion, greatly, influences, cool, gaining,
# Nearest to or: identify, keep, just, quite, retail, animals, whilst, mount,
# Nearest to he: asked, died, met, she, went, fire, father, himself,
# Nearest to eight: backing, andrew, winners, rooms, architectural, merchant, five, anniversary,
# Nearest to police: roberts, prevent, demonstrations, trade, trademark, pinker, grimoires, parties,
# Nearest to recorded: seems, battalion, portrayed, entitled, next, tour, company, diplomat,
# Nearest to quite: very, likely, properly, phrases, or, use, paying, more,
# Nearest to pre: trick, disorders, self, known, important, brand, dual, cardinals,
# Nearest to creation: confidences, oxford, assistance, updated, trademark, corporate, opponent, evolved,
# Nearest to dr: peter, pa, swimming, sealing, sect, father, mother, whom,
# Nearest to engineering: platforms, complete, alike, ionosphere, capitalist, gold, madagascar, horizontal,
# Nearest to cost: copper, enlightenment, meets, finger, amber, because, excessive, deck,
# Epoch 2/10 Iteration: 14100 Avg. Training loss: 3.9803 0.1300 sec/batch
# Epoch 2/10 Iteration: 14200 Avg. Training loss: 3.9852 0.1279 sec/batch
# Epoch 2/10 Iteration: 14300 Avg. Training loss: 3.9590 0.1284 sec/batch
# Epoch 2/10 Iteration: 14400 Avg. Training loss: 3.9415 0.1279 sec/batch
# Epoch 2/10 Iteration: 14500 Avg. Training loss: 3.9220 0.1283 sec/batch
# Epoch 2/10 Iteration: 14600 Avg. Training loss: 3.9869 0.1278 sec/batch
# Epoch 2/10 Iteration: 14700 Avg. Training loss: 3.9644 0.1276 sec/batch
# Epoch 2/10 Iteration: 14800 Avg. Training loss: 3.9710 0.1280 sec/batch
# Epoch 2/10 Iteration: 14900 Avg. Training loss: 4.0159 0.1278 sec/batch
# Epoch 2/10 Iteration: 15000 Avg. Training loss: 3.9392 0.1278 sec/batch
# Nearest to six: xiv, started, diary, live, na, lex, october, metres,
# Nearest to b: f, carriers, des, scottish, footballer, d, functions, player,
# Nearest to have: had, has, linked, many, help, interest, individuals, supernatural,
# Nearest to system: continental, operating, shi, progress, copy, code, servers, required,
# Nearest to with: called, while, greatly, communion, off, cool, influences, situation,
# Nearest to or: identify, whilst, just, animals, keep, mount, retail, expression,
# Nearest to he: asked, died, met, she, went, fire, himself, him,
# Nearest to eight: backing, andrew, winners, architectural, merchant, five, rooms, anniversary,
# Nearest to police: roberts, prevent, trade, demonstrations, trademark, samuel, grimoires, pinker,
# Nearest to recorded: seems, battalion, portrayed, entitled, tour, diplomat, next, seconds,
# Nearest to quite: very, likely, properly, phrases, paying, more, or, kept,
# Nearest to pre: trick, disorders, self, brand, important, known, dual, intention,
# Nearest to creation: confidences, assistance, updated, trademark, oxford, corporate, regarding, writers,
# Nearest to dr: peter, pa, sealing, swimming, father, wiltshire, sect, poetry,
# Nearest to engineering: platforms, complete, capitalist, alike, ionosphere, dish, bekaa, dancing,
# Nearest to cost: copper, enlightenment, finger, because, meets, omega, excessive, deck,
# Epoch 2/10 Iteration: 15100 Avg. Training loss: 3.9211 0.1297 sec/batch
# Epoch 2/10 Iteration: 15200 Avg. Training loss: 4.0071 0.1279 sec/batch
# Epoch 2/10 Iteration: 15300 Avg. Training loss: 3.9541 0.1279 sec/batch
# Epoch 2/10 Iteration: 15400 Avg. Training loss: 3.9596 0.1287 sec/batch
# Epoch 2/10 Iteration: 15500 Avg. Training loss: 3.9734 0.1275 sec/batch
# Epoch 2/10 Iteration: 15600 Avg. Training loss: 3.9757 0.1275 sec/batch
# Epoch 2/10 Iteration: 15700 Avg. Training loss: 3.9140 0.1274 sec/batch
# Epoch 2/10 Iteration: 15800 Avg. Training loss: 3.9713 0.1277 sec/batch
# Epoch 2/10 Iteration: 15900 Avg. Training loss: 3.9801 0.1278 sec/batch
# Epoch 2/10 Iteration: 16000 Avg. Training loss: 3.9796 0.1277 sec/batch
# Nearest to six: xiv, diary, started, lex, live, referenced, na, october,
# Nearest to b: f, functions, carriers, d, examples, des, scottish, letters,
# Nearest to have: had, has, linked, many, interest, individuals, help, supernatural,
# Nearest to system: continental, operating, shi, copy, required, progress, code, servers,
# Nearest to with: called, while, communion, off, greatly, like, sister, fatal,
# Nearest to or: identify, just, whilst, keep, chains, expression, hot, animals,
# Nearest to he: asked, died, met, she, went, himself, him, father,
# Nearest to eight: architectural, andrew, backing, five, anniversary, winners, rooms, merchant,
# Nearest to police: roberts, trade, prevent, demonstrations, pinker, trademark, grimoires, dawn,
# Nearest to recorded: seems, battalion, portrayed, seconds, entitled, diplomat, next, challenged,
# Nearest to quite: very, likely, properly, phrases, paying, more, kept, or,
# Nearest to pre: trick, disorders, self, known, important, brand, derives, familiar,
# Nearest to creation: confidences, trademark, assistance, oxford, updated, corporate, regarding, evolved,
# Nearest to dr: peter, sealing, poetry, swimming, pa, wiltshire, vhdl, sect,
# Nearest to engineering: platforms, ionosphere, bekaa, libraries, topics, complete, organisms, capitalist,
# Nearest to cost: copper, enlightenment, because, excessive, finger, meets, amber, button,
# Epoch 2/10 Iteration: 16100 Avg. Training loss: 3.9722 0.1298 sec/batch
# Epoch 2/10 Iteration: 16200 Avg. Training loss: 3.9559 0.1279 sec/batch
# Epoch 2/10 Iteration: 16300 Avg. Training loss: 3.9773 0.1281 sec/batch
# Epoch 2/10 Iteration: 16400 Avg. Training loss: 3.9796 0.1280 sec/batch
# Epoch 2/10 Iteration: 16500 Avg. Training loss: 3.9365 0.1278 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 3.9165 0.1277 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 3.8937 0.1279 sec/batch
# Epoch 2/10 Iteration: 16800 Avg. Training loss: 3.9653 0.1279 sec/batch
# Epoch 2/10 Iteration: 16900 Avg. Training loss: 3.9275 0.1275 sec/batch
# Epoch 2/10 Iteration: 17000 Avg. Training loss: 3.9222 0.1287 sec/batch
# Nearest to six: xiv, diary, started, lex, referenced, neglected, na, live,
# Nearest to b: d, f, footballer, musician, scottish, des, friedrich, painter,
# Nearest to have: had, has, linked, many, help, individuals, interest, others,
# Nearest to system: operating, continental, copy, shi, progress, required, servers, code,
# Nearest to with: while, called, off, sister, like, greatly, influences, having,
# Nearest to or: identify, just, whilst, expression, keep, hot, quite, retail,
# Nearest to he: asked, died, met, him, she, went, himself, father,
# Nearest to eight: anniversary, backing, andrew, five, architectural, merchant, winners, rooms,
# Nearest to police: roberts, prevent, demonstrations, trade, grimoires, pinker, trademark, compromise,
# Nearest to recorded: seems, portrayed, seconds, battalion, entitled, challenged, tour, next,
# Nearest to quite: very, likely, properly, phrases, paying, more, kept, or,
# Nearest to pre: trick, disorders, self, important, known, brand, derives, ancestry,
# Nearest to creation: confidences, trademark, updated, oxford, regarding, corporate, assistance, concept,
# Nearest to dr: peter, sealing, sect, poetry, pa, wiltshire, atlas, father,
# Nearest to engineering: platforms, ionosphere, disciplines, bekaa, complete, html, topics, libraries,
# Nearest to cost: enlightenment, copper, because, excessive, increase, button, meets, finger,
# Epoch 2/10 Iteration: 17100 Avg. Training loss: 3.9756 0.1321 sec/batch
# Epoch 2/10 Iteration: 17200 Avg. Training loss: 3.9912 0.1345 sec/batch
# Epoch 2/10 Iteration: 17300 Avg. Training loss: 3.9332 0.1362 sec/batch
# Epoch 2/10 Iteration: 17400 Avg. Training loss: 3.9804 0.1295 sec/batch
# Epoch 2/10 Iteration: 17500 Avg. Training loss: 3.9237 0.1275 sec/batch
# Epoch 2/10 Iteration: 17600 Avg. Training loss: 3.9637 0.1278 sec/batch
# Epoch 2/10 Iteration: 17700 Avg. Training loss: 3.9587 0.1282 sec/batch
# Epoch 2/10 Iteration: 17800 Avg. Training loss: 3.9276 0.1278 sec/batch
# Epoch 2/10 Iteration: 17900 Avg. Training loss: 3.9696 0.1279 sec/batch
# Epoch 2/10 Iteration: 18000 Avg. Training loss: 3.9606 0.1277 sec/batch
# Nearest to six: started, xiv, diary, referenced, neglected, julia, live, metres,
# Nearest to b: f, d, footballer, functions, carriers, des, musician, letters,
# Nearest to have: had, has, many, linked, individuals, interest, help, others,
# Nearest to system: continental, shi, copy, operating, progress, required, servers, code,
# Nearest to with: while, called, greatly, communion, like, situation, sister, having,
# Nearest to or: identify, whilst, just, keep, expression, chains, retail, hot,
# Nearest to he: asked, died, met, she, him, himself, father, went,
# Nearest to eight: backing, andrew, anniversary, five, winners, architectural, moscow, rooms,
# Nearest to police: roberts, prevent, demonstrations, trade, grimoires, matthew, dawn, pinker,
# Nearest to recorded: seems, portrayed, challenged, battalion, entitled, seconds, tour, lorne,
# Nearest to quite: very, likely, properly, phrases, paying, more, kept, or,
# Nearest to pre: trick, disorders, self, important, brand, known, familiar, derives,
# Nearest to creation: confidences, trademark, oxford, updated, regarding, assistance, writers, concept,
# Nearest to dr: peter, sealing, pa, wiltshire, vhdl, w, poetry, atlas,
# Nearest to engineering: platforms, topics, ionosphere, disciplines, libraries, html, maryland, bekaa,
# Nearest to cost: enlightenment, copper, because, excessive, increase, increasing, goods, meets,
# Epoch 2/10 Iteration: 18100 Avg. Training loss: 3.9509 0.1298 sec/batch
# Epoch 2/10 Iteration: 18200 Avg. Training loss: 3.9191 0.1282 sec/batch
# Epoch 2/10 Iteration: 18300 Avg. Training loss: 3.9117 0.1280 sec/batch
# Epoch 2/10 Iteration: 18400 Avg. Training loss: 3.9384 0.1277 sec/batch
# Epoch 2/10 Iteration: 18500 Avg. Training loss: 3.9146 0.1274 sec/batch
# Epoch 2/10 Iteration: 18600 Avg. Training loss: 3.9955 0.1281 sec/batch
# Epoch 2/10 Iteration: 18700 Avg. Training loss: 3.9494 0.1278 sec/batch
# Epoch 2/10 Iteration: 18800 Avg. Training loss: 3.9994 0.1280 sec/batch
# Epoch 2/10 Iteration: 18900 Avg. Training loss: 3.9063 0.1278 sec/batch
# Epoch 2/10 Iteration: 19000 Avg. Training loss: 3.9781 0.1278 sec/batch
# Nearest to six: started, xiv, referenced, diary, metres, live, neglected, julia,
# Nearest to b: footballer, f, musician, d, carriers, des, jacques, player,
# Nearest to have: had, has, many, linked, interest, individuals, help, offer,
# Nearest to system: operating, continental, shi, copy, required, code, servers, progress,
# Nearest to with: while, called, greatly, off, gaining, sister, communion, like,
# Nearest to or: whilst, identify, just, keep, expression, retail, boats, passacaglia,
# Nearest to he: asked, died, met, him, she, himself, fire, father,
# Nearest to eight: backing, anniversary, andrew, five, merchant, architectural, completed, winners,
# Nearest to police: roberts, prevent, demonstrations, trade, grimoires, pinker, congress, dachshunds,
# Nearest to recorded: seems, battalion, portrayed, seconds, challenged, entitled, tour, next,
# Nearest to quite: very, likely, properly, phrases, paying, kept, more, ethical,
# Nearest to pre: trick, disorders, self, brand, important, known, derives, familiar,
# Nearest to creation: confidences, oxford, updated, regarding, concept, writers, assistance, trademark,
# Nearest to dr: peter, sealing, pa, poetry, w, wiltshire, vhdl, father,
# Nearest to engineering: platforms, ionosphere, libraries, topics, disciplines, bekaa, research, html,
# Nearest to cost: enlightenment, copper, because, goods, increase, effective, button, increasing,
# Epoch 2/10 Iteration: 19100 Avg. Training loss: 3.9459 0.1305 sec/batch
# Epoch 2/10 Iteration: 19200 Avg. Training loss: 3.9728 0.1277 sec/batch
# Epoch 2/10 Iteration: 19300 Avg. Training loss: 3.9330 0.1310 sec/batch
# Epoch 2/10 Iteration: 19400 Avg. Training loss: 3.9523 0.1277 sec/batch
# Epoch 2/10 Iteration: 19500 Avg. Training loss: 3.9569 0.1278 sec/batch
# Epoch 2/10 Iteration: 19600 Avg. Training loss: 3.9500 0.1284 sec/batch
# Epoch 2/10 Iteration: 19700 Avg. Training loss: 3.9726 0.1389 sec/batch
# Epoch 2/10 Iteration: 19800 Avg. Training loss: 3.9640 0.1388 sec/batch
# Epoch 2/10 Iteration: 19900 Avg. Training loss: 3.9384 0.1408 sec/batch
# Epoch 2/10 Iteration: 20000 Avg. Training loss: 3.9485 0.1321 sec/batch
# Nearest to six: started, referenced, xiv, diary, neglected, metres, live, five,
# Nearest to b: f, footballer, d, des, musician, carriers, phrenology, letters,
# Nearest to have: had, has, many, linked, interest, already, offer, individuals,
# Nearest to system: continental, operating, copy, required, shi, code, servers, progress,
# Nearest to with: while, greatly, sister, called, off, situation, like, having,
# Nearest to or: whilst, identify, just, keep, passacaglia, retail, mount, pfc,
# Nearest to he: asked, died, met, him, she, himself, father, fire,
# Nearest to eight: backing, anniversary, andrew, five, architectural, merchant, completed, rooms,
# Nearest to police: roberts, prevent, demonstrations, trade, pinker, grimoires, matthew, congress,
# Nearest to recorded: portrayed, seconds, seems, battalion, entitled, challenged, tour, gif,
# Nearest to quite: very, likely, properly, phrases, paying, kept, more, ethical,
# Nearest to pre: trick, disorders, self, known, important, rhetorically, brand, derives,
# Nearest to creation: confidences, oxford, regarding, trademark, updated, assistance, concept, history,
# Nearest to dr: peter, w, sealing, pa, wiltshire, poetry, father, atlas,
# Nearest to engineering: platforms, ionosphere, topics, libraries, bekaa, disciplines, html, management,
# Nearest to cost: copper, enlightenment, because, per, increase, goods, deck, button,
# Epoch 2/10 Iteration: 20100 Avg. Training loss: 3.9524 0.1322 sec/batch
# Epoch 2/10 Iteration: 20200 Avg. Training loss: 3.9503 0.1307 sec/batch
# Epoch 2/10 Iteration: 20300 Avg. Training loss: 3.9501 0.1302 sec/batch
# Epoch 2/10 Iteration: 20400 Avg. Training loss: 3.9415 0.1319 sec/batch
# Epoch 2/10 Iteration: 20500 Avg. Training loss: 3.9163 0.1306 sec/batch
# Epoch 2/10 Iteration: 20600 Avg. Training loss: 3.9735 0.1393 sec/batch
# Epoch 2/10 Iteration: 20700 Avg. Training loss: 3.9056 0.1296 sec/batch
# Epoch 2/10 Iteration: 20800 Avg. Training loss: 3.9618 0.1291 sec/batch
# Epoch 2/10 Iteration: 20900 Avg. Training loss: 3.9366 0.1290 sec/batch
# Epoch 2/10 Iteration: 21000 Avg. Training loss: 3.9793 0.1291 sec/batch
# Nearest to six: started, referenced, metres, na, xiv, julia, neglected, diary,
# Nearest to b: f, functions, footballer, d, des, letters, examples, phrenology,
# Nearest to have: had, has, many, linked, bias, offer, interest, individuals,
# Nearest to system: continental, operating, copy, progress, required, shi, servers, code,
# Nearest to with: while, greatly, like, sister, called, situation, gaining, off,
# Nearest to or: identify, whilst, just, keep, passacaglia, either, expression, pfc,
# Nearest to he: asked, died, met, him, she, himself, father, isn,
# Nearest to eight: backing, five, anniversary, andrew, architectural, completed, fm, moscow,
# Nearest to police: roberts, prevent, demonstrations, trade, pinker, grimoires, dachshunds, congress,
# Nearest to recorded: portrayed, seems, challenged, seconds, entitled, tour, battalion, lorne,
# Nearest to quite: very, likely, properly, phrases, paying, kept, more, successfully,
# Nearest to pre: trick, disorders, rhetorically, brand, self, important, known, ayeyarwady,
# Nearest to creation: confidences, oxford, trademark, updated, regarding, concept, salvia, commerce,
# Nearest to dr: peter, w, sealing, pa, poetry, father, wiltshire, atlas,
# Nearest to engineering: platforms, ionosphere, bekaa, libraries, disciplines, topics, management, research,
# Nearest to cost: copper, enlightenment, because, increase, goods, per, increasing, deck,
# Epoch 2/10 Iteration: 21100 Avg. Training loss: 3.7699 0.1312 sec/batch
# Epoch 2/10 Iteration: 21200 Avg. Training loss: 3.5573 0.1289 sec/batch
# Epoch 2/10 Iteration: 21300 Avg. Training loss: 3.7596 0.1287 sec/batch
# Epoch 2/10 Iteration: 21400 Avg. Training loss: 3.8068 0.1285 sec/batch
# Epoch 2/10 Iteration: 21500 Avg. Training loss: 3.8955 0.1287 sec/batch
# Epoch 2/10 Iteration: 21600 Avg. Training loss: 3.9054 0.1287 sec/batch
# Epoch 2/10 Iteration: 21700 Avg. Training loss: 3.9247 0.1292 sec/batch
# Epoch 2/10 Iteration: 21800 Avg. Training loss: 3.9605 0.1287 sec/batch
# Epoch 2/10 Iteration: 21900 Avg. Training loss: 3.9288 0.1291 sec/batch
# Epoch 2/10 Iteration: 22000 Avg. Training loss: 3.9312 0.1286 sec/batch
# Nearest to six: started, xiv, referenced, metres, neglected, diary, julia, transputer,
# Nearest to b: footballer, d, f, musician, scottish, soldier, jacques, des,
# Nearest to have: had, has, many, linked, having, disgusted, individuals, interest,
# Nearest to system: continental, operating, progress, copy, required, shi, servers, code,
# Nearest to with: while, greatly, sister, like, having, called, off, situation,
# Nearest to or: whilst, identify, just, passacaglia, either, chains, expression, person,
# Nearest to he: asked, died, met, fire, isn, himself, him, went,
# Nearest to eight: backing, anniversary, five, andrew, architectural, moscow, completed, merchant,
# Nearest to police: roberts, prevent, pinker, dachshunds, grimoires, trade, demonstrations, compromise,
# Nearest to recorded: portrayed, challenged, entitled, seconds, tour, seems, battalion, trivia,
# Nearest to quite: very, likely, properly, phrases, paying, kept, more, lyme,
# Nearest to pre: trick, disorders, rhetorically, self, known, georges, brand, important,
# Nearest to creation: confidences, oxford, updated, salvia, assistance, trademark, commerce, core,
# Nearest to dr: peter, w, pa, sealing, wiltshire, poetry, wiring, father,
# Nearest to engineering: platforms, ionosphere, bekaa, libraries, disciplines, topics, research, management,
# Nearest to cost: copper, enlightenment, goods, increase, because, per, deck, effective,
# Epoch 2/10 Iteration: 22100 Avg. Training loss: 3.9827 0.1312 sec/batch
# Epoch 2/10 Iteration: 22200 Avg. Training loss: 3.9596 0.1289 sec/batch
# Epoch 2/10 Iteration: 22300 Avg. Training loss: 3.8845 0.1350 sec/batch
# Epoch 2/10 Iteration: 22400 Avg. Training loss: 3.9753 0.1289 sec/batch
# Epoch 2/10 Iteration: 22500 Avg. Training loss: 3.9458 0.1395 sec/batch
# Epoch 2/10 Iteration: 22600 Avg. Training loss: 3.9052 0.1424 sec/batch
# Epoch 2/10 Iteration: 22700 Avg. Training loss: 3.9528 0.1305 sec/batch
# Epoch 2/10 Iteration: 22800 Avg. Training loss: 3.9794 0.1303 sec/batch
# Epoch 2/10 Iteration: 22900 Avg. Training loss: 3.9602 0.1289 sec/batch
# Epoch 2/10 Iteration: 23000 Avg. Training loss: 3.9117 0.1292 sec/batch
# Nearest to six: started, xiv, referenced, diary, metres, neglected, julia, live,
# Nearest to b: f, footballer, functions, d, cameo, des, phrenology, carriers,
# Nearest to have: had, has, many, linked, having, disgusted, individuals, offer,
# Nearest to system: operating, continental, progress, copy, required, code, servers, shi,
# Nearest to with: while, greatly, sister, like, situation, called, gaining, having,
# Nearest to or: identify, whilst, either, passacaglia, just, chains, pfc, expression,
# Nearest to he: asked, died, met, himself, him, isn, she, fire,
# Nearest to eight: anniversary, backing, five, semi, completed, andrew, architectural, merchant,
# Nearest to police: roberts, prevent, demonstrations, grimoires, dachshunds, trade, pinker, force,
# Nearest to recorded: portrayed, challenged, tour, entitled, seconds, seems, pieces, battalion,
# Nearest to quite: very, likely, properly, phrases, paying, kept, because, more,
# Nearest to pre: trick, disorders, rhetorically, georges, known, self, brand, ayeyarwady,
# Nearest to creation: confidences, oxford, trademark, core, updated, salvia, assistance, concept,
# Nearest to dr: peter, w, sealing, pa, father, wiltshire, poetry, wiring,
# ...
# Nearest to eight: five, six, passed, maia, aversion, carotid, andrew, three,
# Nearest to police: defense, civilian, officer, army, comics, air, force, branches,
# Nearest to recorded: performances, records, record, written, albums, tour, produced, album,
# Nearest to quite: very, relatively, lyme, highly, kept, because, paying, impious,
# Nearest to pre: marked, civilization, boasting, classical, renaissance, era, kinship, exist,
# Nearest to creation: creator, genesis, concept, oxford, idea, elgin, design, preston,
# Nearest to dr: david, orchestral, w, sealing, arana, j, nine, robert,
# Nearest to engineering: engineers, chemistry, disciplines, bekaa, management, ionosphere, agricultural, business,
# Nearest to cost: quality, costs, effective, price, speed, enterprises, unit, markets,
# Epoch 10/10 Iteration: 113100 Avg. Training loss: 3.8442 0.1308 sec/batch
# Epoch 10/10 Iteration: 113200 Avg. Training loss: 3.8942 0.1277 sec/batch
# Epoch 10/10 Iteration: 113300 Avg. Training loss: 3.8903 0.1279 sec/batch
# Epoch 10/10 Iteration: 113400 Avg. Training loss: 3.9086 0.1279 sec/batch
# Epoch 10/10 Iteration: 113500 Avg. Training loss: 3.9031 0.1282 sec/batch
# Epoch 10/10 Iteration: 113600 Avg. Training loss: 3.9314 0.1279 sec/batch
# Epoch 10/10 Iteration: 113700 Avg. Training loss: 3.9139 0.1280 sec/batch
# Epoch 10/10 Iteration: 113800 Avg. Training loss: 3.9167 0.1278 sec/batch
# Epoch 10/10 Iteration: 113900 Avg. Training loss: 3.8915 0.1279 sec/batch
# Epoch 10/10 Iteration: 114000 Avg. Training loss: 3.9155 0.1282 sec/batch
# Nearest to six: five, robo, postman, four, eight, segment, three, vest,
# Nearest to b: containing, container, overlay, moorcock, soldier, phrenology, electromagnets, purchases,
# Nearest to have: has, had, having, already, kare, including, subgroup, prefer,
# Nearest to system: systems, operating, telephone, interaction, coordinate, keynesians, polanski, alcibiades,
# Nearest to with: while, develop, turgidson, between, struts, sister, sera, partner,
# Nearest to or: either, simply, identify, holding, fg, ancyra, preventing, direct,
# Nearest to he: she, it, himself, him, his, professor, cabling, rough,
# Nearest to eight: five, passed, maia, andrew, aversion, six, carotid, backing,
# Nearest to police: defense, civilian, officer, army, comics, air, force, branches,
# Nearest to recorded: performances, records, record, written, albums, tour, produced, tracks,
# Nearest to quite: very, relatively, lyme, highly, kept, because, impious, embankment,
# Nearest to pre: marked, civilization, boasting, exhibition, classical, kinship, pro, ayeyarwady,
# Nearest to creation: creator, genesis, oxford, concept, idea, elgin, design, preston,
# Nearest to dr: david, orchestral, w, sealing, arana, j, hoover, compose,
# Nearest to engineering: engineers, chemistry, disciplines, bekaa, management, ionosphere, agricultural, business,
# Nearest to cost: quality, costs, effective, price, speed, enterprises, unit, markets,
# Epoch 10/10 Iteration: 114100 Avg. Training loss: 3.9242 0.1309 sec/batch
# Epoch 10/10 Iteration: 114200 Avg. Training loss: 3.8944 0.1277 sec/batch
# Epoch 10/10 Iteration: 114300 Avg. Training loss: 3.9045 0.1278 sec/batch
# Epoch 10/10 Iteration: 114400 Avg. Training loss: 3.9260 0.1278 sec/batch
# Epoch 10/10 Iteration: 114500 Avg. Training loss: 3.9134 0.1281 sec/batch
# Epoch 10/10 Iteration: 114600 Avg. Training loss: 3.9236 0.1275 sec/batch
# Epoch 10/10 Iteration: 114700 Avg. Training loss: 3.8461 0.1279 sec/batch
# Epoch 10/10 Iteration: 114800 Avg. Training loss: 3.8822 0.1285 sec/batch
# Epoch 10/10 Iteration: 114900 Avg. Training loss: 3.8336 0.1278 sec/batch
# Epoch 10/10 Iteration: 115000 Avg. Training loss: 3.9284 0.1285 sec/batch
# Nearest to six: five, robo, postman, eight, four, three, selamat, segment,
# Nearest to b: container, soldier, containing, electromagnets, overlay, phrenology, purchases, moorcock,
# Nearest to have: has, had, having, already, subgroup, kare, prefer, including,
# Nearest to system: systems, operating, telephone, coordinate, interaction, alcibiades, keynesians, polanski,
# Nearest to with: while, develop, turgidson, struts, partner, sister, between, sera,
# Nearest to or: either, simply, identify, fg, holding, direct, offering, etc,
# Nearest to he: she, it, himself, him, his, professor, cabling, father,
# Nearest to eight: five, passed, maia, andrew, six, backing, aversion, carotid,
# Nearest to police: defense, civilian, officer, army, air, comics, force, military,
# Nearest to recorded: performances, records, record, written, tour, albums, produced, album,
# Nearest to quite: very, relatively, lyme, highly, kept, because, impious, how,
# Nearest to pre: marked, civilization, boasting, pro, ayeyarwady, kinship, classical, gunned,
# Nearest to creation: creator, genesis, concept, oxford, idea, design, elgin, story,
# Nearest to dr: david, w, orchestral, sealing, j, arana, lovecraft, ralph,
# Nearest to engineering: engineers, chemistry, disciplines, bekaa, management, agricultural, ionosphere, mnp,
# Nearest to cost: quality, costs, effective, price, enterprises, speed, markets, unit,
# Epoch 10/10 Iteration: 115100 Avg. Training loss: 3.9170 0.1303 sec/batch
# Epoch 10/10 Iteration: 115200 Avg. Training loss: 3.9457 0.1278 sec/batch
# Epoch 10/10 Iteration: 115300 Avg. Training loss: 3.8936 0.1281 sec/batch
# Epoch 10/10 Iteration: 115400 Avg. Training loss: 3.9147 0.1282 sec/batch
# Epoch 10/10 Iteration: 115500 Avg. Training loss: 3.8960 0.1280 sec/batch
# Epoch 10/10 Iteration: 115600 Avg. Training loss: 3.9150 0.1281 sec/batch
# Epoch 10/10 Iteration: 115700 Avg. Training loss: 3.9138 0.1279 sec/batch
# Epoch 10/10 Iteration: 115800 Avg. Training loss: 3.9367 0.1282 sec/batch
# Epoch 10/10 Iteration: 115900 Avg. Training loss: 3.9104 0.1283 sec/batch
# Epoch 10/10 Iteration: 116000 Avg. Training loss: 3.8916 0.1281 sec/batch
# Nearest to six: five, robo, postman, four, eight, segment, three, january,
# Nearest to b: containing, container, overlay, moorcock, soldier, phrenology, electromagnets, purchases,
# Nearest to have: has, had, having, already, subgroup, goths, prefer, including,
# Nearest to system: systems, telephone, operating, interaction, coordinate, keynesians, alcibiades, extract,
# Nearest to with: while, develop, struts, turgidson, sister, reflection, between, crushing,
# Nearest to or: either, simply, identify, holding, fg, ancyra, overlord, coincident,
# Nearest to he: she, it, himself, him, his, professor, cabling, rough,
# Nearest to eight: five, passed, maia, aversion, andrew, six, backing, carotid,
# Nearest to police: defense, civilian, officer, army, air, force, military, comics,
# Nearest to recorded: performances, records, record, tour, written, albums, produced, album,
# Nearest to quite: very, relatively, lyme, highly, kept, because, impious, extremely,
# Nearest to pre: marked, civilization, boasting, kinship, esper, gunned, pro, european,
# Nearest to creation: creator, genesis, concept, oxford, idea, elgin, story, design,
# Nearest to dr: david, w, orchestral, sealing, j, arana, lovecraft, robert,
# Nearest to engineering: engineers, chemistry, disciplines, bekaa, management, ionosphere, agricultural, mnp,
# Nearest to cost: quality, costs, effective, price, enterprises, speed, markets, unit,
# Epoch 10/10 Iteration: 116100 Avg. Training loss: 3.9211 0.1303 sec/batch
# Epoch 10/10 Iteration: 116200 Avg. Training loss: 3.9136 0.1277 sec/batch
# Epoch 10/10 Iteration: 116300 Avg. Training loss: 3.8916 0.1275 sec/batch
# Epoch 10/10 Iteration: 116400 Avg. Training loss: 3.9061 0.1279 sec/batch
# Epoch 10/10 Iteration: 116500 Avg. Training loss: 3.9249 0.1278 sec/batch
# Epoch 10/10 Iteration: 116600 Avg. Training loss: 3.8964 0.1278 sec/batch
# Epoch 10/10 Iteration: 116700 Avg. Training loss: 3.9193 0.1283 sec/batch
# Epoch 10/10 Iteration: 116800 Avg. Training loss: 3.9118 0.1279 sec/batch
# Epoch 10/10 Iteration: 116900 Avg. Training loss: 3.8849 0.1286 sec/batch
# Epoch 10/10 Iteration: 117000 Avg. Training loss: 3.9326 0.1276 sec/batch
# Nearest to six: five, robo, postman, four, eight, three, segment, january,
# Nearest to b: containing, container, overlay, moorcock, soldier, phrenology, electromagnets, purchases,
# Nearest to have: has, had, having, already, including, prefer, goths, subgroup,
# Nearest to system: systems, telephone, operating, interaction, liszt, keynesians, alcibiades, autonomously,
# Nearest to with: while, develop, between, struts, developing, constitute, reflection, turgidson,
# Nearest to or: either, simply, identify, holding, fg, etc, zambia, offering,
# Nearest to he: she, it, himself, him, his, professor, cabling, father,
# Nearest to eight: five, passed, maia, aversion, andrew, six, carotid, backing,
# Nearest to police: civilian, defense, army, officer, force, air, military, comics,
# Nearest to recorded: performances, records, record, written, tour, albums, produced, album,
# Nearest to quite: very, relatively, lyme, highly, kept, impious, because, extremely,
# Nearest to pre: marked, civilization, boasting, european, kinship, classical, renaissance, gunned,
# Nearest to creation: creator, genesis, oxford, concept, elgin, idea, zog, story,
# Nearest to dr: david, w, orchestral, j, sealing, arana, robert, lovecraft,
# Nearest to engineering: engineers, chemistry, bekaa, disciplines, management, ionosphere, agricultural, mnp,
# Nearest to cost: quality, costs, price, effective, speed, enterprises, unit, markets,
# Epoch 10/10 Iteration: 117100 Avg. Training loss: 3.9386 0.1300 sec/batch
# Epoch 10/10 Iteration: 117200 Avg. Training loss: 3.8421 0.1279 sec/batch
# Epoch 10/10 Iteration: 117300 Avg. Training loss: 3.9089 0.1281 sec/batch
# Epoch 10/10 Iteration: 117400 Avg. Training loss: 3.9239 0.1282 sec/batch
# Epoch 10/10 Iteration: 117500 Avg. Training loss: 3.8470 0.1284 sec/batch
# Epoch 10/10 Iteration: 117600 Avg. Training loss: 3.4693 0.1282 sec/batch
# Epoch 10/10 Iteration: 117700 Avg. Training loss: 3.7576 0.1279 sec/batch
# Epoch 10/10 Iteration: 117800 Avg. Training loss: 3.6836 0.1288 sec/batch
# Epoch 10/10 Iteration: 117900 Avg. Training loss: 3.8508 0.1278 sec/batch
# Epoch 10/10 Iteration: 118000 Avg. Training loss: 3.8857 0.1279 sec/batch
# Nearest to six: five, robo, eight, postman, segment, four, three, alan,
# Nearest to b: container, containing, soldier, electromagnets, overlay, d, phrenology, purchases,
# Nearest to have: had, has, having, already, subgroup, prefer, kare, goths,
# Nearest to system: systems, telephone, operating, interaction, liszt, keynesians, alcibiades, autonomously,
# Nearest to with: while, develop, sister, turgidson, fatal, struts, partner, sera,
# Nearest to or: either, simply, identify, holding, fg, offering, ought, zambia,
# Nearest to he: it, she, himself, him, his, professor, cabling, father,
# Nearest to eight: five, passed, andrew, maia, six, moscow, aversion, percussive,
# Nearest to police: civilian, defense, officer, army, force, air, military, comics,
# Nearest to recorded: performances, records, record, albums, tour, written, produced, tracks,
# Nearest to quite: very, relatively, lyme, highly, kept, impious, because, how,
# Nearest to pre: marked, civilization, kinship, boasting, european, pro, esper, era,
# Nearest to creation: creator, genesis, oxford, concept, design, establishment, elgin, idea,
# Nearest to dr: david, w, j, orchestral, nine, sealing, arana, lovecraft,
# Nearest to engineering: engineers, chemistry, bekaa, disciplines, management, ionosphere, mnp, agricultural,
# Nearest to cost: quality, costs, price, effective, speed, enterprises, unit, markets,
# Epoch 10/10 Iteration: 118100 Avg. Training loss: 3.8918 0.1300 sec/batch
# Epoch 10/10 Iteration: 118200 Avg. Training loss: 3.9022 0.1279 sec/batch
# Epoch 10/10 Iteration: 118300 Avg. Training loss: 3.9137 0.1279 sec/batch
# Epoch 10/10 Iteration: 118400 Avg. Training loss: 3.9041 0.1282 sec/batch
# Epoch 10/10 Iteration: 118500 Avg. Training loss: 3.9145 0.1277 sec/batch
# Epoch 10/10 Iteration: 118600 Avg. Training loss: 3.9531 0.1281 sec/batch
# Epoch 10/10 Iteration: 118700 Avg. Training loss: 3.8530 0.1279 sec/batch
# Epoch 10/10 Iteration: 118800 Avg. Training loss: 3.9336 0.1278 sec/batch
# Epoch 10/10 Iteration: 118900 Avg. Training loss: 3.9109 0.1276 sec/batch
# Epoch 10/10 Iteration: 119000 Avg. Training loss: 3.8731 0.1276 sec/batch
# Nearest to six: five, robo, four, eight, postman, three, segment, january,
# Nearest to b: containing, container, moorcock, overlay, soldier, phrenology, electromagnets, purchases,
# Nearest to have: has, had, having, already, goths, prefer, including, subgroup,
# Nearest to system: systems, telephone, operating, interaction, alcibiades, coordinate, keynesians, liszt,
# Nearest to with: while, develop, sera, struts, between, turgidson, sister, crushing,
# Nearest to or: either, simply, identify, etc, fg, holding, ancyra, zambia,
# Nearest to he: she, it, himself, him, his, professor, cabling, father,
# Nearest to eight: five, passed, six, maia, aversion, andrew, carotid, three,
# Nearest to police: defense, civilian, army, officer, force, military, air, security,
# Nearest to recorded: performances, records, record, tour, albums, tracks, produced, album,
# Nearest to quite: very, relatively, highly, lyme, kept, because, impious, how,
# Nearest to pre: marked, civilization, kinship, boasting, exhibition, european, era, esper,
# Nearest to creation: creator, genesis, oxford, concept, design, idea, zog, elgin,
# Nearest to dr: david, w, orchestral, sealing, j, arana, hoover, cousin,
# Nearest to engineering: engineers, chemistry, bekaa, disciplines, management, ionosphere, mnp, business,
# Nearest to cost: quality, costs, price, effective, speed, enterprises, unit, markets,
# Epoch 10/10 Iteration: 119100 Avg. Training loss: 3.8860 0.1300 sec/batch
# Epoch 10/10 Iteration: 119200 Avg. Training loss: 3.9338 0.1280 sec/batch
# Epoch 10/10 Iteration: 119300 Avg. Training loss: 3.9173 0.1282 sec/batch
# Epoch 10/10 Iteration: 119400 Avg. Training loss: 3.8964 0.1279 sec/batch
# Epoch 10/10 Iteration: 119500 Avg. Training loss: 3.7460 0.1281 sec/batch
# Epoch 10/10 Iteration: 119600 Avg. Training loss: 3.8594 0.1278 sec/batch
# Epoch 10/10 Iteration: 119700 Avg. Training loss: 3.8608 0.1284 sec/batch
# Epoch 10/10 Iteration: 119800 Avg. Training loss: 3.7550 0.1279 sec/batch
# Epoch 10/10 Iteration: 119900 Avg. Training loss: 3.8890 0.1274 sec/batch
# Epoch 10/10 Iteration: 120000 Avg. Training loss: 3.9312 0.1277 sec/batch
# Nearest to six: five, robo, postman, four, eight, segment, three, january,
# Nearest to b: containing, container, soldier, overlay, moorcock, electromagnets, phrenology, purchases,
# Nearest to have: has, had, having, already, prefer, goths, including, kare,
# Nearest to system: systems, operating, telephone, alcibiades, nt, polanski, keynesians, sangha,
# Nearest to with: while, sera, develop, sister, between, reflection, developing, partner,
# Nearest to or: either, simply, identify, fg, ancyra, holding, overlord, etc,
# Nearest to he: she, himself, it, him, his, professor, cabling, father,
# Nearest to eight: five, passed, andrew, maia, six, aversion, carotid, percussive,
# Nearest to police: defense, civilian, army, officer, force, air, military, branches,
# Nearest to recorded: performances, records, record, albums, tour, produced, tracks, album,
# Nearest to quite: very, relatively, highly, lyme, kept, impious, because, extremely,
# Nearest to pre: civilization, marked, boasting, kinship, european, pro, exhibition, era,
# Nearest to creation: creator, genesis, concept, oxford, idea, elgin, design, establishment,
# Nearest to dr: david, orchestral, w, sealing, j, hoover, arana, nine,
# Nearest to engineering: engineers, chemistry, bekaa, disciplines, management, ionosphere, mnp, physics,
# Nearest to cost: quality, costs, price, effective, enterprises, speed, markets, low,
# Epoch 10/10 Iteration: 120100 Avg. Training loss: 3.8950 0.1302 sec/batch
# Epoch 10/10 Iteration: 120200 Avg. Training loss: 3.8514 0.1279 sec/batch
# Epoch 10/10 Iteration: 120300 Avg. Training loss: 3.8591 0.1280 sec/batch
# Epoch 10/10 Iteration: 120400 Avg. Training loss: 3.8742 0.1277 sec/batch
# Epoch 10/10 Iteration: 120500 Avg. Training loss: 3.9485 0.1282 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)

# %% [markdown]
# ## Analogie estimation

# %%
class Embedding:
    def __init__(self, matrix, vocab_to_int, int_to_vocab):
        self.mat = matrix # V * D
        self.vocab_to_int = vocab_to_int
        self.int_to_vocab = int_to_vocab
       
        norms = np.linalg.norm(self.mat, axis = 1, keepdims = True)
        self.mat_normalized = self.mat / norms
        
        
    def most_similar(self, positive, negative):
        a,b = positive        
        c = negative
        id_a, id_b, id_c = vocab_to_int[a], vocab_to_int[b], vocab_to_int[c]
        x = self.mat_normalized[id_a] + self.mat_normalized[id_b] - self.mat_normalized[id_c]
        x /= np.linalg.norm(x)
        distance = [(u, np.dot(x, self.mat_normalized[u])) for u in range(len(self.mat))]
        distance.sort(reverse = True, key=itemgetter(1))
        return [(self.int_to_vocab[x[0]], x[1]) for x in distance[:5]]
    
    def most_similar_words(self, w):        
        id_w = vocab_to_int[w]        
        v = self.mat_normalized[id_w]
        distance = [(u, np.dot(v, self.mat_normalized[u])) for u in range(len(self.mat)) if u != id_w]
        distance.sort(reverse = True, key=itemgetter(1))
        return [(self.int_to_vocab[x[0]], x[1]) for x in distance[:5]]

# %%
my_embedding = Embedding(embed_mat, vocab_to_int, int_to_vocab)

# %%
my_embedding.most_similar(('male', 'woman'), 'man')
# Out:
# [('male', 0.74411446),
#  ('female', 0.53720051),
#  ('infant', 0.49793833),
#  ('woman', 0.48402134),
#  ('mortality', 0.48041493)]

# %%
my_embedding.most_similar_words('paris')
# Out:
# [('louis', 0.42235455),
#  ('france', 0.41963714),
#  ('venice', 0.41912514),
#  ('du', 0.41724244),
#  ('la', 0.41083184)]

# %%
my_embedding.most_similar_words('center')
# Out:
# [('centre', 0.46131477),
#  ('align', 0.41814142),
#  ('sculpture', 0.41384351),
#  ('axe', 0.4071674),
#  ('green', 0.39281508)]

# %%
my_embedding.most_similar_words('happy')
# Out:
# [('songwriter', 0.45090586),
#  ('my', 0.44610384),
#  ('travelling', 0.418964),
#  ('adaptations', 0.4018504),
#  ('guest', 0.40117019)]

# %%
my_embedding.most_similar_words('country')
# Out:
# [('railways', 0.42849112),
#  ('done', 0.41941419),
#  ('radiocommunication', 0.41586366),
#  ('highways', 0.41139176),
#  ('demographics', 0.40123016)]

# %%
my_embedding.most_similar_words('best')
# Out:
# [('award', 0.49729162),
#  ('better', 0.49404368),
#  ('awards', 0.43275812),
#  ('selling', 0.41363564),
#  ('golden', 0.41113827)]

# %%
my_embedding.most_similar_words('who')
# Out:
# [('whose', 0.5392862),
#  ('whom', 0.47186622),
#  ('asahel', 0.42725587),
#  ('young', 0.42506269),
#  ('conjunctivitis', 0.39935061)]
